# %%
from src.config import settings
from pymilvus import MilvusClient
client = MilvusClient(
    uri = settings.ZILLIZ_ENDPOINT, 
    user = settings.ZILLIZ_USER, 
    password = settings.ZILLIZ_PASSWORD
)

# %%
candidate_1 = {
    'chat_id': '34747507-0',
    'name': '王充',
}
candidate_2 = {
    'candidate_id': '461802492279219212',
    'name': '胡修齐',
}

print(client.query('CN_candidates',
    filter=f"chat_id == '{candidate_1['chat_id']}'"
))

print(client.query('CN_candidates',
    filter=f"name == '{candidate_1['name']}'"
))

candidate_2 = client.query('CN_candidates',
    filter=f"candidate_id == '{candidate_2['candidate_id']}'"
)[0]
print(candidate_2)
print(client.query('CN_candidates',
    filter=f"name LIKE '{candidate_2['name']}%'"
))
# Out:
# data: ["{'resume_text': '王充\\n 刚刚活跃\\n34岁  10年以上  本科  离职-随时到岗\\n● 带领团队将老项目重构并且上线，多年团队管理经验。\\n● 企业级RAG开发经验。\\n● 独立完成企业级AI项目的研发落地与优化。\\n● 对算法研究兴趣浓厚，业务抽象能力强。具备创造性思维，能够将全新想法转化为工程应用。对研究工作充满热情，具备良好的团队合作精神和沟通能力。\\n● 学习能力强，有创造性思维能力，有较强分析和解决问题的能力，勤于学习，不断完善自我。\\n● 能熟练阅读技术文档,富有团队精神,责任感和沟通能力，工作积极主动，有较强的责任心和严谨的工作作风。\\n● 善于与人沟通,热爱分享,乐观开朗,积极向上。\\n● 人工智能与移动端前端经验。\\n\\n期望职位\\n---\\n北京大模型算法行业不限30-40K\\n\\n工作经历\\n---\\n捷信消费金融有限公司\\n自然语言处理算法\\n2019.12 - 2025.08\\n工作描述：\\n• 负责公司客服中心智能问答系统开发，利用NLP 技术和大模型实现意图识别与多轮对话。\\n• 负责新技术调研与分享，包括大模型微调与RAG 技术的应用。\\n• 负责搭建RAG 项目所需的向量数据库Milvus，数据缓存数据库Redis 与MySQL。\\n• 负责对人工智能领域新技术的调研与优化。\\n• 负责跨部门协调，推动AI解决方案落地。\\n• 负责AI模块的架构设计。\\n• 负责收集基于生产环境的真实用户语料收集。\\n\\n自动问答智能客服模型加速/性能优化知识图谱Agent聊天机器人\\n\\n百度\\niOS\\n2015.03 - 2019.11\\n工作描述：\\n• 补充技术文档，整理历史代码，修改Bug，负责产品定制功能的修改和维护。\\n• 独立完成APP的发布与审核。\\n• 负责解决开发过程中的技术问题。\\n• 负责优化客户端软件相关产品适配。\\n• 参与与其他团队的沟通协调。\\n• 负责整体APP架构设计。\\n\\n内存管理iOS SDKRunLoopRuntimeObjective-C\\n\\n北京丰业颐和科技有限公司\\niOS\\n2013.06 - 2015.01\\n负责遵照项目需求完成相关应用的设计和开发，准确实现开发需求\\n独立完成系统模块或小系统的设计和代码的实现\\n负责解决开发过程中的技术问题\\n根据项目经理需求编写功能实现.\\n与UI设计人员和后台开发人员交互\\n学习和研究新技术来满足产品需求\\n\\nObjective-C\\n\\n项目经验\\n---\\n捷信智能问答系统\\n自然语言处理算法\\n2024.02 - 至今\\n业绩：\\n显著提升企业内部信息获取效率，降低客服培训成本，为业务决策提供数据支撑，实现企业知识管理的数字化转型。\\n系统上线后自动应答率超80%，人工客服压力降低约50%。\\n内容：\\n项目描述：基于公司JIRA系统数据与客服数据，构建企业内部智能问答平台，为业务分析师与客服人员提供快速、准确的业务咨询服务，显著提升工作效率与服务质量。\\n\\n责任描述：\\n负责系统架构设计，采用RAG技术架构，实现高效的知识检索与智能问答。\\n设计并实现数据预处理流程，整合JIRA系统数据与客服历史数据，构建企业知识库。\\n搭建Milvus向量数据库，设计多集合存储策略，支持客服、业务、开发等不同类型知识的隔离管理与高效检索。\\n使用RAG查询增强策略，例如HyDE（假设文档嵌入）、子查询、回退提示策略，用来提高查询精度。\\n搭建Redis数据库实现高频问答对的缓存。\\n优化检索逻辑，提升问题匹配速度，确保业务咨询的准确性与时效性。\\n与业务部门紧密协作，收集用户反馈，持续优化系统功能与用户体验。\\n\\n技术成果：\\n系统响应时间从传统查询的分钟级缩短至秒级，提高员工工作效率。\\n大副减少业务分析师的重复咨询，大副减少新业务的分析时间。\\n构建了内部企业知识库，支持多维度智能检索。\\n通过RAG技术实现知识实时更新，确保业务信息的时效性与准确性。\\n基于Dify的智能数据标注系统\\n自然语言处理算法\\n2023.08 - 至今\\n项目描述：针对传统数据标注成本高、周期长、质量不稳定等问题，基于Dify平台构建了智能数据标注系统，通过少量高质量标注数据自动生成大规模训练数据集，解决了AI模型训练中数据稀缺的核心痛点。\\n\\n责任描述：\\n基于Dify构建可视化AI工作流，实现快速原型开发。\\n构建多专家融合的标注质量评估模型。\\n针对不同业务场景定制化标注规则和模板。\\n全自动化脚本运行，节省数据标注成本。\\n捷信智能问答系统评估Agent\\n自然语言处理算法\\n2025.03 - 2025.08\\n项目描述：负责设计并实现企业级GraphRag智能问答系统的全方位评估平台，覆盖智能客服系统和基于Jira的本地知识库问答系统，为公司AI产品质量保障提供技术支撑。\\n责任描述：\\n负责整体评估平台的架构设计与方案指定。\\n负责设计例如Redis/MySQL缓存效率、Neo4j知识图谱质量、Milvus查询质量、BGE-M3向量评估策略\\n负责设计意图识别模型准确性、LLM方案选择系统、BGE-Rerank重排序效果评估策略。\\n负责设计Rag系统评估Agent，并根据不同指标分别设计解决方案。\\n根据评估平台报警，对公司Rag系统进行优化。\\n智能语音外呼系统\\n自然语言处理算法\\n2023.07 - 2024.02\\n项目描述：针对传统人工外呼成本高、效率低、合规风险大的问题，基于Whisper ASR和TTS技术构建了智能语音外呼系统，实现自动化客户触达和意向筛选，大幅提升外呼效率和合规性。\\n\\n责任描述：\\n基于Whisper模型实现高精度语音识别，支持方言和噪音环境。\\n集成多情感TTS引擎，生成自然流畅的语音内容。\\n基于BERT模型进行客户同意/拒绝意图分类。\\n集成短信网关，实现自动短信发送。\\nHomeCredit智能客服\\n自然语言处理算法\\n2023.01 - 2023.12\\n项目描述：针对公司客服系统存在的客户信息识别效率低、人工录入错误率高、服务响应时间长等问题，设计并开发了基于深度学习的智能客服NER系统，实现客户意图自动识别和关键信息精准提取。\\n\\n责任描述：\\n基于BERT-Chinese模型进行领域微调，构建金融领域NER模型。\\n使用CasRel架构，实现用户信息抽取。\\n基于公司数据构建知识图谱，支持实体链接和关系推理。\\n设计多层级实体识别架构，支持15种金融实体类型识别。\\n负责对本地大模型ChatGLM进行微调。\\n\\n技术成果：\\n优化模型结构，将识别召回率从78%提升至90.3%。\\n实现模型量化压缩，推理速度提升3倍，内存占用减少60%。\\n捷信金融\\nios开发高级工程师\\n2019.06 - 2023.11\\n业绩：\\n1.通过进行 RN与 Flutter 转型，提高了近一半的开发效率。\\n2.优化了老项目的各种程序错误，降低了线上 crash 频率。\\n3.实际项目四年，没有发生一次生产问题。\\n4.通过分析生产用户行为，与产品经理讨论优化方案并实现上线。\\n内容：\\n《捷信消费金融有限公司》是首批经银监会批准的四家持牌消费金融公司之一，提供银行级安全、专业、便捷的小额贷款、分期购物、消费贷款、手机分期、短期借钱、消费贷，循环额度等服务。\\n主要运用到的技术；\\n1.微信小程序的编写。\\n2.负责 iOS 客户端的审核与发布。\\n3.为原生代码重构,进行 RN 转型。\\n4.运用 JS 进行 RN, flutter 开发。\\n捷信金融风控系统\\n自然语言处理算法\\n2022.09 - 2023.01\\n项目描述：负责设计并开发捷信消费金融智能风控系统，构建覆盖贷前、贷中、贷后全生命周期的风险管控平台。实现快速实时风控决策，支持多场景风险识别和自动化处置。\\n责任描述：\\n负责数据的采集与清洗。\\n负责使用随机森林、XGBoost、逻辑回归构建模型集成Stacking技术进行欺诈识别。\\n负责新技术的调研与实现。\\n负责实现模型A/B测试平台，支持在线模型效果对比和灰度发布。\\n捷信金融商家\\n自然语言处理算法\\n2018.12 - 2022.05\\n项目链接：\\nhttps：//apps.apple.com/cn/app/zong-heng-xiao-shuo-yuan-chuang/id1332590702\\n项目描述：捷信金融商家\\n项目责任：通过与公司的PM，BA，SA交流制定最终开发方案，并参与新需求的开发\\n主要运用到的技术；\\n1.微信小程序的编写。\\n2.负责iOS客户端的审核与发布。\\n3.为前端native代码重构，进行RN转型。\\n4.运用JS进行RN，flutter开发。\\n纵横小说\\nios高级开发工程师\\n2015.01 - 2018.06\\n业绩：\\n1.主要负责iOS移动平台的程序设计、开发\\n2.负责iOS客户端的审核与发布\\n3.负责核心阅读器代码编写与优化\\n4.完成iOS移动平台BUG的修改\\n内容：\\n项目链接:\\nhttps //itunes.ap ...
# data: [], extra_info: {'cost': 1}
# {'name': '李佶', 'updated_at': '2025-11-08T02:46:58.894990', 'full_resume': None, 'candidate_id': '461802492279219212', 'job_applied': '', 'last_message': '您好，请补充：能否提供代表性PR/patch或说明您在Xorg/Qt与显卡透传方面的关键改动？替换tcmalloc为jemalloc时的perf基准数据或CPU占用对比？进程/NUMA绑定如何测得30%提升？两项专利的公开编号或简要摘要？“千万级访问”和代码量相关的监控数据？最近一年实际编码占比是多少？大模型适配（千问/昇腾/A800）您负责了哪些落地工作？有问题请告诉我。', 'metadata': {}, 'analysis': {'skill': 9, 'startup_fit': 7, 'background': 9, 'overall': 9, 'summary': '候选人在C++/Rust/C#等底层语言、语音（声纹、语音转写）与图形/显卡虚拟化（GPU透传、Xorg/Qt、Spice/QXL）方面经验丰富；熟悉性能分析（perf）、内存分配器替换（jemalloc/tcmalloc）、ARM迁移、PRELOAD/NUMA绑定及大模型适配，正向关键词很多（声纹、显卡透传、Xorg、GPU适配、大模型）；唯一需核实的点为部分成果（代码行数、“千万级访问”、30%性能提升、专利细节）是否有量化证明。整体非常匹配语音/视频/图形开发岗位，可进一步沟通近期实际编码占比和具体技术细节。', 'followup_tips': '面试重点核实：近期手写代码比例、GPU/Xorg改动实际patch、perf定位与jemalloc替换细节、两项专利与大模型实战案例。'}, 'chat_id': '98462274-0', 'resume_text': '李佶\r\n 刚刚活跃\r\n52岁  10年以上  硕士  离职-随时到岗\r\n多年软件开发经验，软件质量稳定可靠，卓越解决问题能力；\r\n精通c++,rust,c#,golang，java等主流开发语言和各种框架技术；\r\n熟悉大语言模型框架、原理和应用开发；\r\n对软件产品完整周期深入实践经验；\r\n与团队成员密切协作，为整体目标做出贡献，并积极帮助团队成员共同进步。\r\n\r\n期望职位\r\n---\r\n北京语音/视频/图形开发行业不限25-30K\r\n\r\n工作经历\r\n---\r\n飞腾信息技术有限公司\r\n售前技术支持\r\n·\r\n开放实验室\r\n2025.04 - 2025.09\r\n业绩：\r\n主要项目：\r\n2025.4-2025.4 海南中小学智慧教育平台迁移\r\n从x86安装包，分析该应用为Electron应用；\r\n提取asar文件，修改部分代码，重新打包为arm原生应用\r\n2025.5-2025.5 振华Apollo无人车迁移到Arm平台处理器占用率高\r\n借助perf等工具并结合源代码进行分析；\r\n定位为Arm平台GetBackTrace成本过高，用Jemalloc替换tcmalloc解决；\r\n2025.4-现在，程序开发：进程与处理器内核动态绑定\r\n借助PRELOAD注入定制so ，拦截进程启动（execv*）和子进程fork；\r\n根据定义对亲缘进程进行处理器绑定和内存numa绑定，性能提升30%以上；\r\n\r\n其它项目：宣武医院迁移、大连农行POC、用友k8s资产云和数据中台优化等。\r\n内容：\r\n公司介绍：\r\n公司主营业务：基于Armv8架构的处理器研发、整机研发，主要产品为：服务器处理器S5000C系列，桌面D3000系列及终端。\r\n工作职责：为各类x86应用移植到飞腾桌面或服务器提供解决方案和性能优化方案。\r\n项目与技术环境介绍：\r\n麒麟或统信操作系统/C/C++/Qemu/k8s/docker/wine/box64/fex-emu\r\n\r\n主要职责：\r\n程序开发： 进程与处理器内核动态绑定；\r\n程序迁移到Arm平台后性能优化；\r\n现有x86应用迁移到arm平台的虚拟化实施方案；\r\n在arm平台实施x86应用的转译研究和实施；\r\n\r\n北京凝思软件股份有限公司\r\n技术经理\r\n·\r\n研发中心\r\n2020.09 - 2024.12\r\n业绩：\r\n1. 成功实现显卡从物理机到虚拟机的技术透传，有效解决了虚拟化环境下的显示兼容性问题，确保项目符合沧州云桌面部署的投标入围标准。\r\n2. 针对磁盘加密问题提出并实施解决方案，助力产品顺利通过安全认证，增强了产品的市场竞争力。\r\n3. 积极参与技术创新，独立编写两份专利，分别于2022年及2024年公示，体现了卓越的技术研发与创新能力。\r\n4. 主导实施基于Ceph的分布式文件系统项目，系统已成功上线并通过验收，显著提升了公司数据处理和存储能力。\r\n5. 推动公司AI技术发展，成功适配千问与华为昇腾平台，并构建基于英伟达A800的AI桌面应用，为公司开拓了新的业务机遇。\r\n6.内部培训：《Rust语言与内核开发》、《Transformer原理》、《深度学习数学基础》、《R语言实现时间序列》\r\n内容：\r\n1.云桌面研发；\r\n2.分布式文件系统实施和运维；\r\n3.集群和多路径运维；\r\n4.大数据和 AI 平台构建；\r\n5.专利撰写；\r\n\r\n后端开发系统搭建系统架构前端开发移动开发\r\n\r\n北京远鉴信息技术有限公司\r\nC++\r\n·\r\n工程交付中心\r\n2015.12 - 2020.09\r\n业绩：\r\n1.声纹采集仪。 深圳、黑龙江和河南等多省采用。 无需要到现场解决的故障，客户和代理商总体满意度高。\r\n2.算法库封装。 在多个重要客户现场部署，日均访问量达千万级别，基本无故障（性能和内存泄漏等故障）。\r\n3.声纹鉴定仪。总代码超过6万，负责其中约4万行的开发。在安防和司法领域得到应用，无重大故障（崩溃、死机、卡顿等）。\r\n内容：\r\n(1)声纹鉴定仪开发；C++代码4万行；\r\n(2)语音采集仪开发；C#代码2万行；\r\n(3)语音转写 web 服务开发；C++/Python 代码7000行；\r\n(4)声纹识别算法库（C/C++）封装成 python和 java库；C/C++代码3000行；\r\n\r\nC/C++后端开发语音处理\r\n\r\n北京国交信通科技发展有限公司\r\n技术经理\r\n·\r\n北斗导航办公室\r\n2012.03 - 2015.12\r\n业绩：\r\n1.成功实施了海上搜救系统；\r\n2.研发并成功实施了海上信息播报系统；\r\n内容：\r\n1.负责实施广乐高速公路应急预案系统；\r\n2.负责实施和运维海上搜救系统；\r\n3.负责研发海上信息播报系统；\r\n\r\n系统搭建后端开发React\r\n\r\n康维科技\r\n运维工程师\r\n·\r\n技术支持\r\n2005.12 - 2012.03\r\n业绩：\r\n1、为采用公司 BSS 产品的上海电信、北京电信、四川电信和浙江电信业务成功上线提供支持；\r\n2、复现了全部技术问题，无遗留技术问题；\r\n内容：\r\n1、电信计费、账务、结算和 CRM 系统的二线支持；\r\n2、产品现场咨询和实施；\r\n\r\nCC++JavaPythonShellSQL\r\n\r\n北京时力永联公司\r\nC/C++\r\n·\r\n研发中心\r\n1996.08 - 2005.12\r\n业绩：\r\n1、北京移动、中国联通的计费项目实施；\r\n2、上海电信语音聊天室计费账目实施；\r\n内容：\r\n1、计费账务项目实施；\r\n2、网管项目实施；\r\n3、售前和售后技术支持；\r\n\r\nC/C++语音处理后端开发\r\n\r\n项目经验\r\n---\r\nx86_64到arm应用迁移适配\r\n技术负责人\r\n2024.04 - 至今\r\n2025.4-2025.4 海南中小学智慧教育平台迁移x86到arm\r\n从x86安装包，分析该应用为Electron应用；\r\n提取asar文件，修改部分代码，重新打包为arm原生应用\r\n2025.5-2025.5 振华Apollo无人车迁移到Arm平台处理器占用率高\r\n借助perf等工具并结合源代码进行分析；\r\n定位为Arm平台GetBackTrace成本过高，用Jemalloc替换tcmalloc解决；\r\n2025.4-现在，程序开发：进程与处理器内核动态绑定\r\n借助PRELOAD注入定制so ，拦截进程启动（execv*）和子进程fork；\r\n根据定义对亲缘进程进行处理器绑定和内存numa绑定，性能提升30%以上；\r\n\r\n其它项目：宣武医院迁移、大连农行POC、用友k8s资产云和数据中台优化、无锡交管所Colmap和3DGS迁移到arm+Nvidia 4090适配等。\r\n凝思大数据平台\r\n技术经理\r\n2022.09 - 2024.12\r\n业绩：\r\n1、成功实施多个hadoop项目（联参大数据、四川农行、海南南瑞）；\r\n2、对公司内部知识资产进行清洗，借助大模型构建知识图谱；\r\n ...
# data: ["{'resume_text': '李佶\\r\\n 刚刚活跃\\r\\n52岁  10年以上  硕士  离职-随时到岗\\r\\n多年软件开发经验，软件质量稳定可靠，卓越解决问题能力；\\r\\n精通c++,rust,c#,golang，java等主流开发语言和各种框架技术；\\r\\n熟悉大语言模型框架、原理和应用开发；\\r\\n对软件产品完整周期深入实践经验；\\r\\n与团队成员密切协作，为整体目标做出贡献，并积极帮助团队成员共同进步。\\r\\n\\r\\n期望职位\\r\\n---\\r\\n北京语音/视频/图形开发行业不限25-30K\\r\\n\\r\\n工作经历\\r\\n---\\r\\n飞腾信息技术有限公司\\r\\n售前技术支持\\r\\n·\\r\\n开放实验室\\r\\n2025.04 - 2025.09\\r\\n业绩：\\r\\n主要项目：\\r\\n2025.4-2025.4 海南中小学智慧教育平台迁移\\r\\n从x86安装包，分析该应用为Electron应用；\\r\\n提取asar文件，修改部分代码，重新打包为arm原生应用\\r\\n2025.5-2025.5 振华Apollo无人车迁移到Arm平台处理器占用率高\\r\\n借助perf等工具并结合源代码进行分析；\\r\\n定位为Arm平台GetBackTrace成本过高，用Jemalloc替换tcmalloc解决；\\r\\n2025.4-现在，程序开发：进程与处理器内核动态绑定\\r\\n借助PRELOAD注入定制so ，拦截进程启动（execv*）和子进程fork；\\r\\n根据定义对亲缘进程进行处理器绑定和内存numa绑定，性能提升30%以上；\\r\\n\\r\\n其它项目：宣武医院迁移、大连农行POC、用友k8s资产云和数据中台优化等。\\r\\n内容：\\r\\n公司介绍：\\r\\n公司主营业务：基于Armv8架构的处理器研发、整机研发，主要产品为：服务器处理器S5000C系列，桌面D3000系列及终端。\\r\\n工作职责：为各类x86应用移植到飞腾桌面或服务器提供解决方案和性能优化方案。\\r\\n项目与技术环境介绍：\\r\\n麒麟或统信操作系统/C/C++/Qemu/k8s/docker/wine/box64/fex-emu\\r\\n\\r\\n主要职责：\\r\\n程序开发： 进程与处理器内核动态绑定；\\r\\n程序迁移到Arm平台后性能优化；\\r\\n现有x86应用迁移到arm平台的虚拟化实施方案；\\r\\n在arm平台实施x86应用的转译研究和实施；\\r\\n\\r\\n北京凝思软件股份有限公司\\r\\n技术经理\\r\\n·\\r\\n研发中心\\r\\n2020.09 - 2024.12\\r\\n业绩：\\r\\n1. 成功实现显卡从物理机到虚拟机的技术透传，有效解决了虚拟化环境下的显示兼容性问题，确保项目符合沧州云桌面部署的投标入围标准。\\r\\n2. 针对磁盘加密问题提出并实施解决方案，助力产品顺利通过安全认证，增强了产品的市场竞争力。\\r\\n3. 积极参与技术创新，独立编写两份专利，分别于2022年及2024年公示，体现了卓越的技术研发与创新能力。\\r\\n4. 主导实施基于Ceph的分布式文件系统项目，系统已成功上线并通过验收，显著提升了公司数据处理和存储能力。\\r\\n5. 推动公司AI技术发展，成功适配千问与华为昇腾平台，并构建基于英伟达A800的AI桌面应用，为公司开拓了新的业务机遇。\\r\\n6.内部培训：《Rust语言与内核开发》、《Transformer原理》、《深度学习数学基础》、《R语言实现时间序列》\\r\\n内容：\\r\\n1.云桌面研发；\\r\\n2.分布式文件系统实施和运维；\\r\\n3.集群和多路径运维；\\r\\n4.大数据和 AI 平台构建；\\r\\n5.专利撰写；\\r\\n\\r\\n后端开发系统搭建系统架构前端开发移动开发\\r\\n\\r\\n北京远鉴信息技术有限公司\\r\\nC++\\r\\n·\\r\\n工程交付中心\\r\\n2015.12 - 2020.09\\r\\n业绩：\\r\\n1.声纹采集仪。 深圳、黑龙江和河南等多省采用。 无需要到现场解决的故障，客户和代理商总体满意度高。\\r\\n2.算法库封装。 在多个重要客户现场部署，日均访问量达千万级别，基本无故障（性能和内存泄漏等故障）。\\r\\n3.声纹鉴定仪。总代码超过6万，负责其中约4万行的开发。在安防和司法领域得到应用，无重大故障（崩溃、死机、卡顿等）。\\r\\n内容：\\r\\n(1)声纹鉴定仪开发；C++代码4万行；\\r\\n(2)语音采集仪开发；C#代码2万行；\\r\\n(3)语音转写 web 服务开发；C++/Python 代码7000行；\\r\\n(4)声纹识别算法库（C/C++）封装成 python和 java库；C/C++代码3000行；\\r\\n\\r\\nC/C++后端开发语音处理\\r\\n\\r\\n北京国交信通科技发展有限公司\\r\\n技术经理\\r\\n·\\r\\n北斗导航办公室\\r\\n2012.03 - 2015.12\\r\\n业绩：\\r\\n1.成功实施了海上搜救系统；\\r\\n2.研发并成功实施了海上信息播报系统；\\r\\n内容：\\r\\n1.负责实施广乐高速公路应急预案系统；\\r\\n2.负责实施和运维海上搜救系统；\\r\\n3.负责研发海上信息播报系统；\\r\\n\\r\\n系统搭建后端开发React\\r\\n\\r\\n康维科技\\r\\n运维工程师\\r\\n·\\r\\n技术支持\\r\\n2005.12 - 2012.03\\r\\n业绩：\\r\\n1、为采用公司 BSS 产品的上海电信、北京电信、四川电信和浙江电信业务成功上线提供支持；\\r\\n2、复现了全部技术问题，无遗留技术问题；\\r\\n内容：\\r\\n1、电信计费、账务、结算和 CRM 系统的二线支持；\\r\\n2、产品现场咨询和实施；\\r\\n\\r\\nCC++JavaPythonShellSQL\\r\\n\\r\\n北京时力永联公司\\r\\nC/C++\\r\\n·\\r\\n研发中心\\r\\n1996.08 - 2005.12\\r\\n业绩：\\r\\n1、北京移动、中国联通的计费项目实施；\\r\\n2、上海电信语音聊天室计费账目实施；\\r\\n内容：\\r\\n1、计费账务项目实施；\\r\\n2、网管项目实施；\\r\\n3、售前和售后技术支持；\\r\\n\\r\\nC/C++语音处理后端开发\\r\\n\\r\\n项目经验\\r\\n---\\r\\nx86_64到arm应用迁移适配\\r\\n技术负责人\\r\\n2024.04 - 至今\\r\\n2025.4-2025.4 海南中小学智慧教育平台迁移x86到arm\\r\\n从x86安装包，分析该应用为Electron应用；\\r\\n提取asar文件，修改部分代码，重新打包为arm原生应用\\r\\n2025.5-2025.5 振华Apollo无人车迁移到Arm平台处理器占用率高\\r\\n借助perf等工具并结合源代码进行分析；\\r\\n定位为Arm平台GetBackTrace成本过高，用Jemalloc替换tcmalloc解决；\\r\\n2025.4-现在，程序开发：进程与处理器内核动态绑定\\r\\n借助PRELOAD注入定制so ，拦截进程启动（execv*）和子进程fork；\\r\\n根据定义对亲缘进程进行处理器绑定和内存numa绑定，性能提升30%以上；\\r\\n\\r\\n其它项目：宣武医院迁移、大连农行POC、用友k8s资产云和数据中台优化、无锡交管所Colmap和3DGS迁移到arm+Nvidia 4090适配等。\\r\\n凝思大数据平台\\r\\n技术经理\\r\\n2022.09 - 2024.12\\r\\n业绩：\\r\\n1、成功实施多个hadoop项目（联参大数据、四川农行、海南南瑞）；\\r\\n2、对公司内部知识资产进行清洗，借助大模型构建知识图谱；\\r\\n3、申请专利2份：《一种基于层级的路径规划方法和设备》、《一种基于边缘计算的情感识别的方法和设备》；\\r\\n4、为国金证券构建环境：千问2.5适配华为昇腾NPU；\\r\\n5、 基于英伟达A800构建企业内部基于AI的桌面应用（Ollama+Open-webui+python）;\\r\\n6、借助 GlusterFS ，为航天二院构建存储虚拟化池；\\r\\n7、DRBD （分布式块设备）成功实施于咸阳机场；\\r\\n内容：\\r\\n1、基于 Hadoop 构建大数据平台（联参大数据平台，四川农行，海南南瑞）；\\r\\n2、基于 ClickHouse 构建 OLAP 引擎；\\r\\n3、基于 NIFI 构建 ETL 平台；\\r\\n4、构建分布式文件系统，包括：GlusterFS，Ceph FS，gfs2 ，DRBD等；\\r\\n5、大模型适配：千问+华为昇腾910ProB+ 编程助手（Twinny）;\\r\\n6、AI应用开发：Ollama+Open-webUI +Python;\\r\\n云桌面\\r\\n开发工程师\\r\\n2020.09 - 2022.09\\r\\n业绩：\\r\\ ...

# %%
c = candidate_2.copy()
c.pop('resume_vector')
c.pop('resume_text')
c.pop('analysis')
c.pop('last_message')
c.pop('metadata')
c.pop('chat_id')
c.pop('updated_at')
c.pop('conversation_id')
c.pop('name')
c = {k: v for k, v in c.items() if v}
print(c)
result = client.upsert('CN_candidates', data=c, partial_update=True)
result['ids']
# Out:
# 2025-11-11 00:21:49,837 [ERROR][handler]: RPC error: [upsert_rows], <MilvusException: (code=65535, message=failed to unmarshal base json: unexpected end of JSON input)>, <Time:{'RPC start': '2025-11-11 00:21:49.782786', 'RPC error': '2025-11-11 00:21:49.837151'}> (decorators.py:253)
# {'candidate_id': '461802492279219212'}
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[37], line 13
#      12 print(c)
# ---> 13 result = client.upsert('CN_candidates', data=c, partial_update=True)
#      14 result['ids']
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:284, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     283 except Exception as ex:
# --> 284     raise ex from ex
#     286 return OmitZeroDict(
#     287     {
#     288         "upsert_count": res.upsert_count,
#    (...)    293     }
#     294 )
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:280, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     279 try:
# --> 280     res = conn.upsert_rows(
#     281         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     282     )
#     283 except Exception as ex:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:254, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     253     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 254     raise e from e
#     255 except grpc.FutureTimeoutError as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:250, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     249     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 250     return func(*args, **kwargs)
#     251 except MilvusException as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:297, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     296     self.set_onetime_loglevel(level)
# --> 297 return func(self, *args, **kwargs)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:195, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     194     else:
# --> 195         raise e from e
#     196 except Exception as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:165, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     164 try:
# --> 165     return func(*args, **kwargs)
#     166 except grpc.RpcError as e:
#     167     # Do not retry on these codes
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/grpc_handler.py:882, in GrpcHandler.upsert_rows(self, collection_name, entities, partition_name, timeout, **kwargs)
#     875     return self.upsert_rows(
#     876         collection_name=collection_name,
#     877         entities=entities,
#    (...)    880         **kwargs,
#     881     )
# --> 882 check_status(response.status)
#     883 m = MutationResult(response)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/utils.py:66, in check_status(status)
#      65 if status.code != 0 or status.error_code != 0:
# ---> 66     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=failed to unmarshal base json: unexpected end of JSON input)>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[37], line 13
#      12 print(c)
# ---> 13 result = client.upsert('CN_candidates', data=c, partial_update=True)
#      14 result['ids']
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:284, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     283 except Exception as ex:
# --> 284     raise ex from ex
#     286 return OmitZeroDict(
#     287     {
#     288         "upsert_count": res.upsert_count,
#    (...)    293     }
#     294 )
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:280, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     279 try:
# --> 280     res = conn.upsert_rows(
#     281         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     282     )
#     283 except Exception as ex:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:254, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     253     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 254     raise e from e
#     255 except grpc.FutureTimeoutError as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:250, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     249     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 250     return func(*args, **kwargs)
#     251 except MilvusException as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:297, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     296     self.set_onetime_loglevel(level)
# --> 297 return func(self, *args, **kwargs)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:195, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     194     else:
# --> 195         raise e from e
#     196 except Exception as e:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:165, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     164 try:
# --> 165     return func(*args, **kwargs)
#     166 except grpc.RpcError as e:
#     167     # Do not retry on these codes
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/grpc_handler.py:882, in GrpcHandler.upsert_rows(self, collection_name, entities, partition_name, timeout, **kwargs)
#     875     return self.upsert_rows(
#     876         collection_name=collection_name,
#     877         entities=entities,
#    (...)    880         **kwargs,
#     881     )
# --> 882 check_status(response.status)
#     883 m = MutationResult(response)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/utils.py:66, in check_status(status)
#      65 if status.code != 0 or status.error_code != 0:
# ---> 66     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=failed to unmarshal base json: unexpected end of JSON input)>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[37], line 13
#      11 c = {k: v for k, v in c.items() if v}
#      12 print(c)
# ---> 13 result = client.upsert('CN_candidates', data=c, partial_update=True)
#      14 result['ids']
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:284, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     280     res = conn.upsert_rows(
#     281         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     282     )
#     283 except Exception as ex:
# --> 284     raise ex from ex
#     286 return OmitZeroDict(
#     287     {
#     288         "upsert_count": res.upsert_count,
#    (...)    293     }
#     294 )
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/milvus_client/milvus_client.py:280, in MilvusClient.upsert(self, collection_name, data, timeout, partition_name, **kwargs)
#     278 # Upsert into the collection.
#     279 try:
# --> 280     res = conn.upsert_rows(
#     281         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     282     )
#     283 except Exception as ex:
#     284     raise ex from ex
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:254, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     252     record_dict["RPC error"] = str(datetime.datetime.now())
#     253     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 254     raise e from e
#     255 except grpc.FutureTimeoutError as e:
#     256     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:250, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     248 try:
#     249     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 250     return func(*args, **kwargs)
#     251 except MilvusException as e:
#     252     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:297, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     295 if level:
#     296     self.set_onetime_loglevel(level)
# --> 297 return func(self, *args, **kwargs)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:195, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     193         back_off = min(back_off * back_off_multiplier, max_back_off)
#     194     else:
# --> 195         raise e from e
#     196 except Exception as e:
#     197     raise e from e
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/decorators.py:165, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     163 while True:
#     164     try:
# --> 165         return func(*args, **kwargs)
#     166     except grpc.RpcError as e:
#     167         # Do not retry on these codes
#     168         if e.code() in IGNORE_RETRY_CODES:
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/grpc_handler.py:882, in GrpcHandler.upsert_rows(self, collection_name, entities, partition_name, timeout, **kwargs)
#     874     # recursively calling `upsert_rows` handling another schema change happens during retry
#     875     return self.upsert_rows(
#     876         collection_name=collection_name,
#     877         entities=entities,
#    (...)    880         **kwargs,
#     881     )
# --> 882 check_status(response.status)
#     883 m = MutationResult(response)
#     884 ts_utils.update_collection_ts(collection_name, m.timestamp)
#
# File ~/.local/share/uv/envs/global/lib/python3.13/site-packages/pymilvus/client/utils.py:66, in check_status(status)
#      64 def check_status(status: Status):
#      65     if status.code != 0 or status.error_code != 0:
# ---> 66         raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=65535, message=failed to unmarshal base json: unexpected end of JSON input)>

# %%
# test upsert
candidate_3 = {
    'candidate_id': '11',
    'name': '张三',
    'analysis': {'skill': 9, 'startup_fit': 7, 'background': 9, 'overall': 9, 
    'summary': '非常匹配语音/视频/图形类底层研发岗位：丰富的C/C++/Rust等底层语言经验，声纹/语音转写、显卡透传、Xorg/Qt修改、ARM迁移、perf调优与大模型适配，核心关键字大量命中。', 
    'followup_tips': '面试重点核实：提供代表性PR/patch或代码片段（Xorg/显卡透传改动）；perf基准与替换tcmalloc→jemalloc的对比数据；进程/NUMA绑定测量方法与...级访问”与代码量的监控数据；最近1年实际手写代码占比及在大模型适配中的具体落地职责。'
    },
    'metadata': {'b': 2},
    'resume_text': '张三的简历',
    'resume_vector': [0.1]*1536,
}
try:
    result = client.upsert(
        'CN_candidates', 
        data=candidate_3, 
        partial_update=bool(candidate_3.get('candidate_id'))
    )
    # client.flush('CN_candidates')
    print(result['ids'])
except Exception as e:
    print(e)
# Out:
# ['461802494827812753']

# %%
candidate_4 = {
    'name': '李四',
}
result = client.insert(
    'CN_candidates', 
    data=candidate_4
)
result['ids']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 candidate_4 = {
#       2     'name': '李四',
#       3 }
# ----> 4 result = client.insert(
#       5     'CN_candidates',
#       6     data=candidate_4
#       7 )
#       8 result['ids']
#
# NameError: name 'client' is not defined

# %%
# 
result = client.query('CN_candidates', 
filter=f"candidate_id == '461802494640224045'"
)
result[0]
# Out:
# {'updated_at': None,
#  'resume_text': '张三的简历',
#  'resume_vector': [0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   0.10000000149011612,
#   ...],
#  'name': '张三',
#  'job_applied': None,
#  'last_message': None,
#  'metadata': None,
#  'stage': None,
#  'candidate_id': '461802494640224045',
#  'analysis': None,
#  'full_resume': None,
#  'conversation_id': None,
#  'chat_id': None}
